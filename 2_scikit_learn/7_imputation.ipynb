# %% [markdown]
# # Imputation
#
# * In real life it is common to find datasets with missing information
# * Information is usually represented as NaN or None
# * Scikit-learn models do not work if the dataset has missing values

# %%
import pandas as pd

data =pd.DataFrame([
    ("red", 1, 1.0, -1), ("blue", 2, None, -3), (None, 3, 3.0, -5),
    ("red", 4, 4.0, -2), ("red", None, 5.0, -5), ("blue", 6, 6.0,-1),
    ("red", 7, None), ("blue", 8, 8.0, None), ("green", 9, 9.0, None),
    ("red", 10, 10.0, None),
], columns=["color", "number", "value", "other"])

data
# Out:
#    color  number  value  other
# 0    red     1.0    1.0   -1.0
# 1   blue     2.0    NaN   -3.0
# 2   None     3.0    3.0   -5.0
# 3    red     4.0    4.0   -2.0
# 4    red     NaN    5.0   -5.0
# 5   blue     6.0    6.0   -1.0
# 6    red     7.0    NaN    NaN
# 7   blue     8.0    8.0    NaN
# 8  green     9.0    9.0    NaN
# 9    red    10.0   10.0    NaN

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer()
imputer.fit(data[['value']])
# Out:
# SimpleImputer()

# %%
# Use the average to impute the missing values (by default)

data['value_imputer'] = imputer.transform(data[['value']])
data
# Out:
#    color  number  value  other  value_imputer
# 0    red     1.0    1.0   -1.0           1.00
# 1   blue     2.0    NaN   -3.0           5.75
# 2   None     3.0    3.0   -5.0           3.00
# 3    red     4.0    4.0   -2.0           4.00
# 4    red     NaN    5.0   -5.0           5.00
# 5   blue     6.0    6.0   -1.0           6.00
# 6    red     7.0    NaN    NaN           5.75
# 7   blue     8.0    8.0    NaN           8.00
# 8  green     9.0    9.0    NaN           9.00
# 9    red    10.0   10.0    NaN          10.00

# %%
median_imputer = SimpleImputer(strategy='median')
median_imputer.fit(data[['number']])
data['number_imputed'] = median_imputer.transform(data[['number']])
data
# Out:
#    color  number  value  other  value_imputer  number_imputed
# 0    red     1.0    1.0   -1.0           1.00             1.0
# 1   blue     2.0    NaN   -3.0           5.75             2.0
# 2   None     3.0    3.0   -5.0           3.00             3.0
# 3    red     4.0    4.0   -2.0           4.00             4.0
# 4    red     NaN    5.0   -5.0           5.00             6.0
# 5   blue     6.0    6.0   -1.0           6.00             6.0
# 6    red     7.0    NaN    NaN           5.75             7.0
# 7   blue     8.0    8.0    NaN           8.00             8.0
# 8  green     9.0    9.0    NaN           9.00             9.0
# 9    red    10.0   10.0    NaN          10.00            10.0

# %% [markdown]
# ### Categorical variables

# %%
# To categorical variables

color_imputer = SimpleImputer(strategy='most_frequent')
color_imputer.fit(data[['color']])
data['color_imputed'] = color_imputer.transform(data[['color']])
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jucalfonsom/Developer/mlbootcamp/2_scikit_learn/7_imputation.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell:/Users/jucalfonsom/Developer/mlbootcamp/2_scikit_learn/7_imputation.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> color_imputer = SimpleImputer(strategy='most_frequent')
#       <a href='vscode-notebook-cell:/Users/jucalfonsom/Developer/mlbootcamp/2_scikit_learn/7_imputation.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> color_imputer.fit(data[['color']])
# ----> <a href='vscode-notebook-cell:/Users/jucalfonsom/Developer/mlbootcamp/2_scikit_learn/7_imputation.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> data['color_imputed'] = color_imputer.transform(data[['color']])
#       <a href='vscode-notebook-cell:/Users/jucalfonsom/Developer/mlbootcamp/2_scikit_learn/7_imputation.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> data
#
# File ~/Developer/mlbootcamp/venv/lib/python3.11/site-packages/pandas/core/frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File ~/Developer/mlbootcamp/venv/lib/python3.11/site-packages/pandas/core/frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
#    4302     if (
#    4303         key in self.columns
#    4304         and value.ndim == 1
#    4305         and not isinstance(value.dtype, ExtensionDtype)
#    4306     ):
#    4307         # broadcast across multiple columns if necessary
#    4308         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/Developer/mlbootcamp/venv/lib/python3.11/site-packages/pandas/core/frame.py:5040, in DataFrame._sanitize_column(self, value)
#    5038 if is_list_like(value):
#    5039     com.require_length_match(value, self.index)
# -> 5040 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File ~/Developer/mlbootcamp/venv/lib/python3.11/site-packages/pandas/core/construction.py:603, in sanitize_array(data, index, dtype, copy, allow_2d)
#     601 subarr = data
#     602 if data.dtype == object:
# --> 603     subarr = maybe_infer_to_datetimelike(data)
#     604 elif data.dtype.kind == "U" and using_pyarrow_string_dtype():
#     605     from pandas.core.arrays.string_ import StringDtype
#
# File ~/Developer/mlbootcamp/venv/lib/python3.11/site-packages/pandas/core/dtypes/cast.py:1172, in maybe_infer_to_datetimelike(value)
#    1169     raise TypeError(type(value))  # pragma: no cover
#    1170 if value.ndim != 1:
#    1171     # Caller is responsible
# -> 1172     raise ValueError(value.ndim)  # pragma: no cover
#    1174 if not len(value):
#    1175     return value
#
# ValueError: 2

# %%
color_imputer.transform(data[['color']])
# Out:
# array([['red'],
#        ['blue'],
#        [None],
#        ['red'],
#        ['red'],
#        ['blue'],
#        ['red'],
#        ['blue'],
#        ['green'],
#        ['red']], dtype=object)

# %%
color_imputer.transform(data[['color']]).squeeze()

# Squeeze delete the unnecessary arrays inside a column
# Out:
# array(['red', 'blue', None, 'red', 'red', 'blue', 'red', 'blue', 'green',
#        'red'], dtype=object)

# %%
# To categorical variables

color_imputer = SimpleImputer(strategy='most_frequent', missing_values=pd.NA)
color_imputer.fit(data[['color']])
data['color_imputed'] = color_imputer.transform(data[['color']]).squeeze()
data
# Out:
#    color  number  value  other  value_imputer  number_imputed color_imputed
# 0    red     1.0    1.0   -1.0           1.00             1.0           red
# 1   blue     2.0    NaN   -3.0           5.75             2.0          blue
# 2   None     3.0    3.0   -5.0           3.00             3.0           red
# 3    red     4.0    4.0   -2.0           4.00             4.0           red
# 4    red     NaN    5.0   -5.0           5.00             6.0           red
# 5   blue     6.0    6.0   -1.0           6.00             6.0          blue
# 6    red     7.0    NaN    NaN           5.75             7.0           red
# 7   blue     8.0    8.0    NaN           8.00             8.0          blue
# 8  green     9.0    9.0    NaN           9.00             9.0         green
# 9    red    10.0   10.0    NaN          10.00            10.0           red

# %% [markdown]
# ### Define a costant value

# %%
constant_imputer = SimpleImputer(strategy='constant', fill_value=10)
constant_imputer.fit(data[['other']])
data['constant_imputer'] = constant_imputer.transform(data[['other']])
data
# Out:
#    color  number  value  other  value_imputer  number_imputed color_imputed  \
# 0    red     1.0    1.0   -1.0           1.00             1.0           red
# 1   blue     2.0    NaN   -3.0           5.75             2.0          blue
# 2   None     3.0    3.0   -5.0           3.00             3.0           red
# 3    red     4.0    4.0   -2.0           4.00             4.0           red
# 4    red     NaN    5.0   -5.0           5.00             6.0           red
# 5   blue     6.0    6.0   -1.0           6.00             6.0          blue
# 6    red     7.0    NaN    NaN           5.75             7.0           red
# 7   blue     8.0    8.0    NaN           8.00             8.0          blue
# 8  green     9.0    9.0    NaN           9.00             9.0         green
# 9    red    10.0   10.0    NaN          10.00            10.0           red
#
#    constant_imputer
# 0              -1.0
# 1              -3.0
# 2              -5.0
# 3              -2.0
# 4              -5.0
# 5              -1.0
# 6              10.0
# 7              10.0
# 8              10.0
# 9              10.0
