# %% [markdown]
# # Scaling

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from utils import make_dataset, plot, show_dataframe, plot_dataset

# %%
original_dataset = make_dataset(100)
show_dataframe(original_dataset)
# Out:
#         Weight    Height
# 0   143.678084  1.557356
# 1    61.892825  1.546430
# 2    51.146523  1.617466
# 3   106.920144  1.530850
# 4    91.266365  1.836430
# ..         ...       ...
# 95   67.741961  1.672775
# 96  142.618472  1.622271
# 97  103.930059  1.793195
# 98  146.207403  1.899744
# 99  141.070534  1.764871
#
# [100 rows x 2 columns]

# %%
fig = plt.figure()
ax = fig.gca()
plot(ax, original_dataset, "Original data")
# Out:
# <Axes: title={'center': 'Original data'}>

# %% [markdown]
# # How to scaling

# %% [markdown]
# ## Standardization
#
# Standardization is, perhaps, the most common of scale transformations; it consists of centering all data for an attribute at 0 and making its variance 1.
#
# $$ X_{norm} = (X- \mu)/ \sigma $$
#
#
# This scaler is commonly used when you have data that is normally distributed and you want all your data to have similar scales. Also keep in mind that the range of features is variable. It is also used when you are preparing data for regression or neural networks.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
standard_scaled = scaler.fit_transform(original_dataset)

plot_dataset(
    original_dataset, "Original data",
    standard_scaled, "Standardized data"
)

# %% [markdown]
# # Min-Max scaling
#
# This scaling technique helps us transform the values of our dataset so that they fall within a known range
#
# $$ X_{norm} = (X-X_{min})/(X_{max}-X_{min}) $$
#
# Use this scaler when you want the data to fall between a certain range, in this case, between 0 and 1 by default - especially useful for distance-based models, such as the k-Nearest Neighbors model or SVM. In this case, it doesn't matter much whether your features are normally distributed.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
minmax_dataset = scaler.fit_transform(original_dataset)

plot_dataset(
    original_dataset, "Original data",
    minmax_dataset, "Min-Max scaled data"
)

# %% [markdown]
# # Absolute Maximum Scaling
#
# This scaler transforms the data by dividing it by the absolute maximum value of each variable. This is useful when working with data that has very large or very small values.
#
# $$ X_{scaled} = X/max(abs(X))$$
#
# _MaxAbsScaler_ is a good choice when features are sparse or mostly zero and have variable scales. It is also useful when used in neural networks or sparse linear models such as logistic regression or SVM.

# %%
from sklearn.preprocessing import MaxAbsScaler

scaler = MaxAbsScaler()
scaler.fit(original_dataset)
maxabs_scaled = scaler.transform(original_dataset)

plot_dataset(
    original_dataset, "Original data",
    maxabs_scaled, "Max-abs scaled data"
)

# %% [markdown]
# # Other scalers
#
# * QuantileTransformer
# * RobustScaler
# * PowerTransform
